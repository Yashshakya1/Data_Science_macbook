# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn import linear_model

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
dataset = sns.load_dataset('mpg')
dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
dataset.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
print('-------- Showing the statictic data --------,''\n',dataset.describe())
print('-------- Showing the important information in the given data ----------','\n',dataset.info())
# Out:
# -------- Showing the statictic data --------,
#                mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000
# ...

# %%
dataset.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
dataset['horsepower'] = dataset['horsepower'].fillna(dataset['horsepower']).mean()

# %%
dataset.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# # finding the outlier

# %%
sns.boxenplot(data = dataset, x = 'horsepower', y = 'weight', hue = 'cylinders')
plt.show()

# %%
sns.violinplot(data = dataset,x = 'horsepower', y = 'weight', hue = 'cylinders')
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = np.array(dataset['name']).reshape(1,-1)

# %%
sns.set_style('dark')
sns.barplot(data = dataset , x = 'model_year' , y = 'horsepower')
# Out:
# <Axes: xlabel='model_year', ylabel='horsepower'>

# %%
dataset.describe()
# Out:
#               mpg   cylinders  displacement    horsepower       weight  \
# count  398.000000  398.000000    398.000000  3.980000e+02   398.000000
# mean    23.514573    5.454774    193.425879  1.044694e+02  2970.424623
# std      7.815984    1.701004    104.269838  7.968095e-13   846.841774
# min      9.000000    3.000000     68.000000  1.044694e+02  1613.000000
# 25%     17.500000    4.000000    104.250000  1.044694e+02  2223.750000
# 50%     23.000000    4.000000    148.500000  1.044694e+02  2803.500000
# 75%     29.000000    8.000000    262.000000  1.044694e+02  3608.000000
# max     46.600000    8.000000    455.000000  1.044694e+02  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
columns = ['mpg','cylinders','displacement','weight','acceleration','model_year']

# %%
sns.heatmap(data = dataset[columns].corr() , annot= True)
# Out:
# <Axes: >

# %%
sns.pairplot(data = dataset)

# %% [markdown]
# # encodeing

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
encoding = le.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 3
#       1 from sklearn.preprocessing import LabelEncoder
#       2 le = LabelEncoder()
# ----> 3 encoding = le.fit_transform(x)
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/preprocessing/_label.py:110, in LabelEncoder.fit_transform(self, y)
#      97 def fit_transform(self, y):
#      98     """Fit label encoder and return encoded labels.
#      99
#     100     Parameters
#    (...)    108         Encoded labels.
#     109     """
# --> 110     y = column_or_1d(y, warn=True)
#     111     self.classes_, y = _unique(y, return_inverse=True)
#     112     return y
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:1483, in column_or_1d(y, dtype, warn, device)
#    1470         warnings.warn(
#    1471             (
# ...
