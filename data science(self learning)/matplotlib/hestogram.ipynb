# %%
# graph that shows how data is distributed — it displays the frequency (count) 
# of data points that fall within specific ranges (called bins).

# imp points 
# univariant analysis
# by default bins 10
import matplotlib.pyplot as plt 
import numpy as np 
scros = np.random.randint(1,100,200)
plt.hist(scros,bins=20, color = "purple" , ec = "black",label="data")
print(scros)
plt.xlabel("scores")
plt.ylabel("student")
plt.title("student marks between the 50")
plt.legend()
plt.show()
# Out:
# [74 37 20 93 96 96 44 63 86 73 73 44 87 19 31 25 53 44 47 49 50 16 31 83
#  84 12 18 36 48 10 47  8 26 24 48  9 28 12 57 40 84 14 74  6 81 70 34 93
#  26 21 11 31 65 49  1 22 40 45 61 34 55 23 86 92 26 96 35 29 14 36 81 69
#  45  2 24 89  2  7 56 37 89 63 29 89 22 73 68 61 19 52 40 87 14 91 88 32
#  78 23 80 89 14 30 23 85 22 12 61 67  3 48 92 12 99 97 49 79 74 96 72  9
#  88 68 58  5 73 24  9 45 44 29 11 70 96 77 73 31 60 93 74 63 31 35  3 42
#  52 58 14 22 68  9 92 77 92 16 29  8 96 45 56 63  6 91 17 15 66 79 42 10
#  33 62 95 63 99 67 73 22 33 55 42 11  4 21 75 49 30  9 64  1 70 22 65 72
#  54 32  5 26 12 96 46 31]

# %%
len(scros)
maximum = scros.nunique()
print(maximum)
# w = max - min / no_of_bins
# print(w)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 len(scros)
# ----> 2 maximum = scros.nunique()
#       3 print(maximum)
#       4 # w = max - min / no_of_bins
#       5 # print(w)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'nunique'

# %%
f = [5,9]
max(f)
# Out:
# 9
