# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn

# %%
ds = pd.DataFrame({'Name': ["yash","rs","ps","as"]})

# %%
ds
# Out:
#    Name
# 0  yash
# 1    rs
# 2    ps
# 3    as
