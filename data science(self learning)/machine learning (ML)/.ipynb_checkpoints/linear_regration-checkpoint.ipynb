# %% [markdown]
# 👇
#
# # 🎯 What is Regression?
#
# * Regression is a Supervised Machine Learning technique used to predict continuous values (numbers).
#
# # In simple terms:
#
# * Regression helps you find relationships between variables and predict numeric outcomes.

# %% [markdown]
# | Study Hours | Exam Score |
# | ----------- | ---------- |
# | 1           | 40         |
# | 2           | 50         |
# | 3           | 60         |
# | 4           | 70         |
# | 5           | 80         |
#
# # real life example
# | Problem             | Input (X)                | Output (Y)       |
# | ------------------- | ------------------------ | ---------------- |
# | Predict house price | Area, bedrooms, location | Price (₹)        |
# | Predict salary      | Experience, education    | Salary (₹)       |
# | Predict temperature | Time, location           | Temperature (°C) |
# | Predict sales       | Marketing spend          | Sales amount     |
#
#
# # regression formula
# * y = mx + c
#
# # types of linear regression
#
# | Type                           | Description                       | Output            |
# | ------------------------------ | --------------------------------- | ----------------- |
# | **Linear Regression**          | Predicts using a straight line    | Continuous value  |
# | **Multiple Linear Regression** | Uses more than one feature        | Continuous value  |
# | **Polynomial Regression**      | Uses curved (non-linear) relation | Continuous value  |
# | **Ridge/Lasso Regression**     | Regularized to avoid overfitting  | Continuous value  |
# | **Logistic Regression**        | Used for classification (Yes/No)  | Probability (0–1) |

# %% [markdown]
# # 🔥 Difference Between array() and asarray()
# * ✔ np.array()
# * Always creates a new copy of the data (unless told otherwise).
# * ✔ np.asarray()
# * Creates a view, not a copy, whenever possible → faster.

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
# data
x = np.array([1,2,3,4,5]).reshape(-1,1)
y = np.array([10,30,50,70,90])

# model
model = LinearRegression()
model.fit(x,y)
# Prediction
y_pred = model.predict(x)
# plotting
plt.scatter(x,y, color = 'red', label = 'Actual data')
plt.plot(x,y_pred ,color = 'green' ,label ='fit line')
plt.title('example of linear regression')
plt.xlabel('Study hours')
plt.ylabel('Marks')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Training data
x_axis = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y_axis = np.array([10, 30, 50, 70, 90])

# Create model and fit
model = LinearRegression()
model.fit(x_axis, y_axis)

# Take user input
hours = float(input('Enter your study hours: '))

# Predict
pred = model.predict([[hours]])

# Output
print(f'Study hours: {hours} → Predicted score: {pred[0]:.2f}')
# Out:
# Enter your study hours:  4
# Study hours: 4.0 → Predicted score: 70.00

# %% [markdown]
# # apply LinearRegression on real world Data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

ds = pd.read_csv('pokemon_stats_2025.csv')
ds
# Out:
#      pokedex_id        name  height  weight  base_experience   type_1  type_2  \
# 0             1   Bulbasaur       7      69               64    grass  poison
# 1             2     Ivysaur      10     130              142    grass  poison
# 2             3    Venusaur      20    1000              236    grass  poison
# 3             4  Charmander       6      85               62     fire     NaN
# 4             5  Charmeleon      11     190              142     fire     NaN
# ..          ...         ...     ...     ...              ...      ...     ...
# 245         246    Larvitar       6     720               60     rock  ground
# 246         247     Pupitar      12    1520              144     rock  ground
# 247         248   Tyranitar      20    2020              270     rock    dark
# 248         249       Lugia      52    2160              306  psychic  flying
# 249         250       Ho-oh      38    1990              306     fire  flying
#
#       hp  attack  defense  special_attack  special_defense  speed
# 0     45      49       49              65               65     45
# 1     60      62       63              80               80     60
# 2     80      82       83             100              100     80
# 3     39      52       43              60               50     65
# 4     58      64       58              80               65     80
# ..   ...     ...      ...             ...              ...    ...
# 245   50      64       50              45               50     41
# 246   70      84       70              65               70     51
# 247  100     134      110              95              100     61
# 248  106      90      130              90              154    110
# 249  106     130       90             110              154     90
#
# [250 rows x 13 columns]

# %%
print(ds.describe())
print('-----------------------------------------------------------------------------------------------')
print(ds.info())
# Out:
#        pokedex_id      height       weight  base_experience          hp  \
# count  250.000000  250.000000   250.000000       250.000000  250.000000
# mean   125.500000   11.844000   473.768000       136.244000   66.776000
# std     72.312977   10.117962   617.573294        74.252368   29.779879
# min      1.000000    2.000000     1.000000        36.000000   10.000000
# 25%     63.250000    6.000000    88.500000        65.000000   48.500000
# 50%    125.500000   10.000000   295.000000       142.000000   65.000000
# 75%    187.750000   15.000000   576.250000       175.000000   80.000000
# max    250.000000   92.000000  4600.000000       608.000000  255.000000
#
#            attack     defense  special_attack  special_defense       speed
# count  250.000000  250.000000      250.000000       250.000000  250.000000
# mean    70.944000   68.684000       65.952000        68.452000   65.880000
# std     27.462806   30.439224       27.343525        27.463296   27.286109
# min      5.000000    5.000000       10.000000        20.000000    5.000000
# 25%     50.000000   49.250000       45.000000        50.000000   45.000000
# 50%     70.000000   65.000000       64.000000        65.000000   65.000000
# 75%     90.000000   85.000000       85.000000        84.500000   85.000000
# max    134.000000  230.000000      154.000000       230.000000  150.000000
# -----------------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pokedex_id       250 non-null    int64
#  1   name             250 non-null    object
#  2   height           250 non-null    int64
#  3   weight           250 non-null    int64
#  4   base_experience  250 non-null    int64
#  5   type_1           250 non-null    object
#  6   type_2           115 non-null    object
#  7   hp               250 non-null    int64
#  8   attack           250 non-null    int64
#  9   defense          250 non-null    int64
#  10  special_attack   250 non-null    int64
#  11  special_defense  250 non-null    int64
#  12  speed            250 non-null    int64
# dtypes: int64(10), object(3)
# memory usage: 25.5+ KB
# None

# %%
ds.isnull().sum()
# Out:
# pokedex_id           0
# name                 0
# height               0
# weight               0
# base_experience      0
# type_1               0
# type_2             135
# hp                   0
# attack               0
# defense              0
# special_attack       0
# special_defense      0
# speed                0
# dtype: int64

# %%
ds.dropna(inplace = True)

# %%
ds.isnull().sum()
# Out:
# pokedex_id         0
# name               0
# height             0
# weight             0
# base_experience    0
# type_1             0
# type_2             0
# hp                 0
# attack             0
# defense            0
# special_attack     0
# special_defense    0
# speed              0
# dtype: int64

# %%
ds.columns
# Out:
# Index(['pokedex_id', 'name', 'height', 'weight', 'base_experience', 'type_1',
#        'type_2', 'hp', 'attack', 'defense', 'special_attack',
#        'special_defense', 'speed'],
#       dtype='object')

# %%
ds.drop(columns = 'pokedex_id', inplace = True)

# %%
ds
# Out:
#            name  height  weight  base_experience   type_1  type_2   hp  \
# 0     Bulbasaur       7      69               64    grass  poison   45
# 1       Ivysaur      10     130              142    grass  poison   60
# 2      Venusaur      20    1000              236    grass  poison   80
# 5     Charizard      17     905              240     fire  flying   78
# 11   Butterfree      11     320              178      bug  flying   60
# ..          ...     ...     ...              ...      ...     ...  ...
# 245    Larvitar       6     720               60     rock  ground   50
# 246     Pupitar      12    1520              144     rock  ground   70
# 247   Tyranitar      20    2020              270     rock    dark  100
# 248       Lugia      52    2160              306  psychic  flying  106
# 249       Ho-oh      38    1990              306     fire  flying  106
#
#      attack  defense  special_attack  special_defense  speed
# 0        49       49              65               65     45
# 1        62       63              80               80     60
# 2        82       83             100              100     80
# 5        84       78             109               85    100
# 11       45       50              90               80     70
# ..      ...      ...             ...              ...    ...
# 245      64       50              45               50     41
# 246      84       70              65               70     51
# 247     134      110              95              100     61
# 248      90      130              90              154    110
# 249     130       90             110              154     90
#
# [115 rows x 12 columns]

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
ds['name'] = le.fit_transform(ds['name'])
ds['type_1'] = le.fit_transform(ds['type_1'])
ds['type_2'] = le.fit_transform(ds['type_2'])
# for col in ['name','type_1','type_2']:
#     ds[col] = le.fit_transform(ds[col])

# %%
ds
# Out:
#      name  height  weight  base_experience  type_1  type_2   hp  attack  \
# 0       6       7      69               64       7      10   45      49
# 1      41      10     130              142       7      10   60      62
# 2     104      20    1000              236       7      10   80      82
# 5       8      17     905              240       5       6   78      84
# 11      7      11     320              178       0       6   60      45
# ..    ...     ...     ...              ...     ...     ...  ...     ...
# 245    51       6     720               60      13       8   50      64
# 246    78      12    1520              144      13       8   70      84
# 247   101      20    2020              270      13       0  100     134
# 248    54      52    2160              306      12       6  106      90
# 249    35      38    1990              306       5       6  106     130
#
#      defense  special_attack  special_defense  speed
# 0         49              65               65     45
# 1         63              80               80     60
# 2         83             100              100     80
# 5         78             109               85    100
# 11        50              90               80     70
# ..       ...             ...              ...    ...
# 245       50              45               50     41
# 246       70              65               70     51
# 247      110              95              100     61
# 248      130              90              154    110
# 249       90             110              154     90
#
# [115 rows x 12 columns]

# %% [markdown]
# # extract the input feature x and traget value y

# %%
x = ds.iloc[:,:-1]
y = ds['speed']

print('this is input feature that was x :-',x)
print('the target value :- \n' , y)
# Out:
# this is input feature that was x :-      name  height  weight  base_experience  type_1  type_2   hp  attack  \
# 0       6       7      69               64       7      10   45      49
# 1      41      10     130              142       7      10   60      62
# 2     104      20    1000              236       7      10   80      82
# 5       8      17     905              240       5       6   78      84
# 11      7      11     320              178       0       6   60      45
# ..    ...     ...     ...              ...     ...     ...  ...     ...
# 245    51       6     720               60      13       8   50      64
# 246    78      12    1520              144      13       8   70      84
# 247   101      20    2020              270      13       0  100     134
# 248    54      52    2160              306      12       6  106      90
# 249    35      38    1990              306       5       6  106     130
#
#      defense  special_attack  special_defense
# 0         49              65               65
# 1         63              80               80
# 2         83             100              100
# 5         78             109               85
# 11        50              90               80
# ..       ...             ...              ...
# 245       50              45               50
# 246       70              65               70
# 247      110              95              100
# 248      130              90              154
# 249       90             110              154
#
# [115 rows x 11 columns]
# the target value :-
#  0       45
# 1       60
# 2       80
# 5      100
# 11      70
#       ...
# 245     41
# 246     51
# 247     61
# 248    110
# 249     90
# Name: speed, Length: 115, dtype: int64

# %%
# the shape of this dataset is 

print("Shape of X:", x.shape)
print("Shape of y:", y.shape)
print("Dataset shape:", ds.shape)
# Out:
# Shape of X: (115, 11)
# Shape of y: (115,)
# Dataset shape: (115, 12)

# %% [markdown]
# # check correlation

# %%
corr_matrix = ds.select_dtypes(include = [int,float]).corr()
sns.heatmap(corr_matrix,annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # Feature salection

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x = pd.DataFrame(ss.fit_transform(x) , columns = x.columns)

# %%
x
# Out:
#          name    height    weight  base_experience    type_1    type_2  \
# 0   -1.536312 -0.496730 -0.720496        -1.152079 -0.285519  0.695608
# 1   -0.481980 -0.270048 -0.632661         0.011808 -0.285519  0.695608
# 2    1.415817  0.485560  0.620065         1.414439 -0.285519  0.695608
# 3   -1.476064  0.258878  0.483273         1.474126 -0.671809 -0.637641
# 4   -1.506188 -0.194487 -0.359077         0.548986 -1.637534 -0.637641
# ..        ...       ...       ...              ...       ...       ...
# 110 -0.180743 -0.572291  0.216889        -1.211765  0.873352  0.028984
# 111  0.632599 -0.118926  1.368820         0.041651  0.873352  0.028984
# 112  1.325446  0.485560  2.088778         1.921774  0.873352 -2.637515
# 113 -0.090371  2.903504  2.290366         2.458953  0.680207 -0.637641
# 114 -0.662723  1.845654  2.045580         2.458953 -0.671809 -0.637641
#
#            hp    attack   defense  special_attack  special_defense
# 0   -0.976053 -0.819352 -0.686367       -0.136884        -0.184604
# 1   -0.325979 -0.348767 -0.292970        0.408439         0.306818
# 2    0.540786  0.375208  0.269025        1.135537         0.962048
# 3    0.454110  0.447606  0.128526        1.462731         0.470626
# 4   -0.325979 -0.964147 -0.658267        0.771988         0.306818
# ..        ...       ...       ...             ...              ...
# 110 -0.759362 -0.276370 -0.658267       -0.863982        -0.676026
# 111  0.107404  0.447606 -0.096272       -0.136884        -0.020796
# 112  1.407551  2.257545  1.027718        0.953762         0.962048
# 113  1.667581  0.664799  1.589713        0.771988         2.731169
# 114  1.667581  2.112750  0.465723        1.499085         2.731169
#
# [115 rows x 11 columns]

# %% [markdown]
# # split the data on the basis off test and train

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2, random_state=2)
print('this shape is before the splitting the data :-',x.shape)
print('After splitting the data :- ',x_train.shape)
print(x_train)
# Out:
# this shape is before the splitting the data :- (115, 11)
# After splitting the data :-  (92, 11)
#          name    height    weight  base_experience    type_1    type_2  \
# 16   1.566436 -0.270048 -0.647060         0.817575  0.293916 -1.637578
# 0   -1.536312 -0.496730 -0.720496        -1.152079 -0.285519  0.695608
# 3   -1.476064  0.258878  0.483273         1.474126 -0.671809 -0.637641
# 53   0.120495 -0.043365 -0.035096         0.295318  0.680207 -1.637578
# 89   0.963960  0.485560  0.324882         0.459456  1.259642  1.028921
# ..        ...       ...       ...              ...       ...       ...
# 22   0.421733 -0.798973 -0.742094        -1.256530 -1.637534 -0.304329
# 72  -1.686931 -0.194487 -0.337478        -0.018036 -1.637534  0.695608
# 109  1.024208 -0.723412 -0.733455        -1.196843  0.100771  1.028921
# 15  -0.451856 -0.647851 -0.740655        -0.689508  0.293916 -1.637578
# 40  -1.235074  0.032195 -0.255403        -1.181922  0.293916 -0.637641
#
#            hp    attack   defense  special_attack  special_defense
# 16   3.141081 -0.059177 -0.798766        0.590214        -0.676026
# 0   -0.976053 -0.819352 -0.686367       -0.136884        -0.184604
# 3    0.454110  0.447606  0.128526        1.462731         0.470626
# 53  -1.192744 -0.964147 -0.236771        1.135537         1.617278
# 89   1.190860  0.121817  0.184725        1.135537         1.289663
# ..        ...       ...       ...             ...              ...
# 22  -1.409435 -0.059177 -0.517768       -0.863982        -0.512219
# 72   0.107404  0.664799 -0.096272       -0.318658        -0.020796
# 109 -0.976053 -1.507129 -1.641758        0.590214        -0.184604
# 15   2.057625 -0.964147 -1.501260       -0.863982        -1.495064
# 40  -1.409435  0.483805 -0.798766       -1.227530        -1.167449
#
# [92 rows x 11 columns]

# %% [markdown]
# # creatign the LinearRegression Model

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# -------------------------------------------------------
# 9. PREDICTION SYSTEM
# -------------------------------------------------------

def predict_speed(name, type_1, type_2, hp, attack, defense, sp_attack, sp_defense, height_m, weight_kg, total):

    row = [[name, type_1, type_2, hp, attack, defense, sp_attack, sp_defense, height_m, weight_kg, total]]

    input_df = pd.DataFrame(row, columns=x.columns)

    input_scaled = ss.transform(input_df)

    prediction = lr.predict(input_scaled)

    return prediction[0]




print("\n------------------- PREDICTION -------------------")


pred = predict_speed(
    name=10,
    type_1=3,
    type_2=5,
    hp=80,
    attack=95,
    defense=85,
    sp_attack=100,
    sp_defense=90,
    height_m=1.7,
    weight_kg=72,
    total=540
)

print(pred)
# Out:
# ------------------- PREDICTION -------------------
# 171.38181955952513
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # find the m and c value

# %%
print('this is the value of C is :-',lr.intercept_)
# Out:
# this is the value of C is :- 65.18655676336058

# %%
print('This is the value of M')
for col,coef in zip(x.columns,lr.coef_):
    print(f'{col} :- {coef}')
# Out:
# This is the value of M
# name :- -0.6236675277932981
# height :- 12.10352376684244
# weight :- -8.143470725287294
# base_experience :- 23.364237241404236
# type_1 :- 5.14443967658501
# type_2 :- -0.08107054418544599
# hp :- -13.711359620810473
# attack :- 8.082321267540285
# defense :- -17.368029246210323
# special_attack :- -0.030244724557731802
# special_defense :- 1.6090212710500085

# %%
from sklearn.metrics import mean_absolute_error,r2_score
y_pred = lr.predict(x_test)
print('performace on this model :-',r2_score(y_test,y_pred))
print('this is the error number :- ',mean_absolute_error(y_test,y_pred))
# Out:
# 0.022348024584826987
# 18.758105463648036
