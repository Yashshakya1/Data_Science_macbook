# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ds = sns.load_dataset('titanic')
ds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
orginal_data = ds['age'].copy()

# %%
ds.boxplot()
plt.show()

# %%
sns.displot(ds['age'] , kde = True)
plt.show()

# %%
# there are 2 ways to handel the outliear that was the trimming and capping

# %% [markdown]
# # trimming

# %%
ds['age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
print(f'highest limit {ds['age'].mean() + 3*ds['age'].std()}')
print(f'lowest limit {ds['age'].mean() - 3*ds['age'].std()}')
# Out:
# highest limit 73.27860964406095
# lowest limit -13.88037434994331

# %%
# detect the outliear 
ds[(ds['age'] > 73.27) | (ds['age'] < -13.80)]
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked  class  who  \
# 630         1       1  male  80.0      0      0  30.000        S  First  man
# 851         0       3  male  74.0      0      0   7.775        S  Third  man
#
#      adult_male deck  embark_town alive  alone
# 630        True    A  Southampton   yes   True
# 851        True  NaN  Southampton    no   True

# %%
# 1st apporach

# %%
new_ds = ds[(ds['age'] <= 73.27) & (ds['age'] >= -13.80)]
new_ds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
plt.subplot(1,2,1)
sns.histplot(orginal_data, kde = True, color = 'red')

plt.subplot(1,2,2)
sns.histplot(ds['age'], kde = True , color = 'green')
plt.show()

# %% [markdown]
# # secand apporach

# %%
ds['age z_score'] = (ds['age'] + ds['age'].mean()) / ds['age'].std()

# %%
ds.head()
ds.shape
# Out:
# (891, 16)

# %% [markdown]
# # detect the outliear

# %%
ds[(ds['age z_score'] > 3) | (ds['age z_score'] < -3)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# # trimming the outliear

# %%
ds[(ds['age z_score'] < 3) & (ds['age z_score'] > -3)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male  2.00      3      1  21.0750        S   Third
# 10          1       3  female  4.00      1      1  16.7000        S   Third
# 16          0       3    male  2.00      4      1  29.1250        Q   Third
# 24          0       3  female  8.00      3      1  21.0750        S   Third
# 43          1       2  female  3.00      1      2  41.5792        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 827         1       2    male  1.00      0      2  37.0042        C  Second
# 831         1       2    male  0.83      1      1  18.7500        S  Second
# 850         0       3    male  4.00      4      2  31.2750        S   Third
# 852         0       3  female  9.00      1      1  15.2458        C   Third
# 869         1       3    male  4.00      1      1  11.1333        S   Third
#
# ...

# %% [markdown]
# # capping

# %%
upper_limit = ds['age'].mean() + 3*ds['age'].std()
lower_limit = ds['age'].mean() - 3*ds['age'].std()
print(upper_limit)
print(lower_limit)
# Out:
# 73.27860964406095
# -13.88037434994331

# %%
ds['age'] = np.where(ds['age'] > upper_limit, upper_limit,
         np.where(ds['age'] < lower_limit, lower_limit
                  ,ds['age'] 
                 )
        )

# %%
ds.shape
# Out:
# (891, 16)

# %%
ds['age'].describe()
# Out:
# count    714.000000
# mean      29.688694
# std       14.492933
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       73.278610
# Name: age, dtype: float64
