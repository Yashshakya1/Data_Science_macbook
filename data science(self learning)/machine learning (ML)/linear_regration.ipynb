# %% [markdown]
# 👇
#
# # 🎯 What is Regression?
#
# * Regression is a Supervised Machine Learning technique used to predict continuous values (numbers).
#
# # In simple terms:
#
# * Regression helps you find relationships between variables and predict numeric outcomes.

# %% [markdown]
# | Study Hours | Exam Score |
# | ----------- | ---------- |
# | 1           | 40         |
# | 2           | 50         |
# | 3           | 60         |
# | 4           | 70         |
# | 5           | 80         |
#
# # real life example
# | Problem             | Input (X)                | Output (Y)       |
# | ------------------- | ------------------------ | ---------------- |
# | Predict house price | Area, bedrooms, location | Price (₹)        |
# | Predict salary      | Experience, education    | Salary (₹)       |
# | Predict temperature | Time, location           | Temperature (°C) |
# | Predict sales       | Marketing spend          | Sales amount     |
#
#
# # regression formula
# * y = mx + c
#
# # types of linear regression
#
# | Type                           | Description                       | Output            |
# | ------------------------------ | --------------------------------- | ----------------- |
# | **Linear Regression**          | Predicts using a straight line    | Continuous value  |
# | **Multiple Linear Regression** | Uses more than one feature        | Continuous value  |
# | **Polynomial Regression**      | Uses curved (non-linear) relation | Continuous value  |
# | **Ridge/Lasso Regression**     | Regularized to avoid overfitting  | Continuous value  |
# | **Logistic Regression**        | Used for classification (Yes/No)  | Probability (0–1) |

# %% [markdown]
# # 🔥 Difference Between array() and asarray()
# * ✔ np.array()
# * Always creates a new copy of the data (unless told otherwise).
# * ✔ np.asarray()
# * Creates a view, not a copy, whenever possible → faster.

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
# data
x = np.array([1,2,3,4,5]).reshape(-1,1)
y = np.array([10,30,50,70,90])

# model
model = LinearRegression()
model.fit(x,y)
# Prediction
y_pred = model.predict(x)
# plotting
plt.scatter(x,y, color = 'red', label = 'Actual data')
plt.plot(x,y_pred ,color = 'green' ,label ='fit line')
plt.title('example of linear regression')
plt.xlabel('Study hours')
plt.ylabel('Marks')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Training data
x_axis = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y_axis = np.array([10, 30, 50, 70, 90])

# Create model and fit
model = LinearRegression()
model.fit(x_axis, y_axis)

# Take user input
hours = float(input('Enter your study hours: '))

# Predict
pred = model.predict([[hours]])

# Output
print(f'Study hours: {hours} → Predicted score: {pred[0]:.2f}')
# Out:
# Enter your study hours:  4
# Study hours: 4.0 → Predicted score: 70.00

# %% [markdown]
# # apply LinearRegression on real world Data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

ds = pd.read_csv('pokemon_stats_2025.csv')
ds
# Out:
#      pokedex_id        name  height  weight  base_experience   type_1  type_2  \
# 0             1   Bulbasaur       7      69               64    grass  poison
# 1             2     Ivysaur      10     130              142    grass  poison
# 2             3    Venusaur      20    1000              236    grass  poison
# 3             4  Charmander       6      85               62     fire     NaN
# 4             5  Charmeleon      11     190              142     fire     NaN
# ..          ...         ...     ...     ...              ...      ...     ...
# 245         246    Larvitar       6     720               60     rock  ground
# 246         247     Pupitar      12    1520              144     rock  ground
# 247         248   Tyranitar      20    2020              270     rock    dark
# 248         249       Lugia      52    2160              306  psychic  flying
# 249         250       Ho-oh      38    1990              306     fire  flying
#
# ...

# %%
print(ds.describe())
print('-----------------------------------------------------------------------------------------------')
print(ds.info())
# Out:
#        pokedex_id      height       weight  base_experience          hp  \
# count  250.000000  250.000000   250.000000       250.000000  250.000000
# mean   125.500000   11.844000   473.768000       136.244000   66.776000
# std     72.312977   10.117962   617.573294        74.252368   29.779879
# min      1.000000    2.000000     1.000000        36.000000   10.000000
# 25%     63.250000    6.000000    88.500000        65.000000   48.500000
# 50%    125.500000   10.000000   295.000000       142.000000   65.000000
# 75%    187.750000   15.000000   576.250000       175.000000   80.000000
# max    250.000000   92.000000  4600.000000       608.000000  255.000000
#
#            attack     defense  special_attack  special_defense       speed
# count  250.000000  250.000000      250.000000       250.000000  250.000000
# mean    70.944000   68.684000       65.952000        68.452000   65.880000
# std     27.462806   30.439224       27.343525        27.463296   27.286109
# ...

# %%
ds.isnull().sum()
# Out:
# pokedex_id           0
# name                 0
# height               0
# weight               0
# base_experience      0
# type_1               0
# type_2             135
# hp                   0
# attack               0
# defense              0
# special_attack       0
# special_defense      0
# speed                0
# dtype: int64

# %%
ds.dropna(inplace = True)

# %%
ds.isnull().sum()
# Out:
# pokedex_id         0
# name               0
# height             0
# weight             0
# base_experience    0
# type_1             0
# type_2             0
# hp                 0
# attack             0
# defense            0
# special_attack     0
# special_defense    0
# speed              0
# dtype: int64

# %%
ds.columns
# Out:
# Index(['pokedex_id', 'name', 'height', 'weight', 'base_experience', 'type_1',
#        'type_2', 'hp', 'attack', 'defense', 'special_attack',
#        'special_defense', 'speed'],
#       dtype='object')

# %%
ds.drop(columns = ['pokedex_id','height'], inplace = True)

# %%
ds
# Out:
#            name  weight  base_experience   type_1  type_2   hp  attack  \
# 0     Bulbasaur      69               64    grass  poison   45      49
# 1       Ivysaur     130              142    grass  poison   60      62
# 2      Venusaur    1000              236    grass  poison   80      82
# 5     Charizard     905              240     fire  flying   78      84
# 11   Butterfree     320              178      bug  flying   60      45
# ..          ...     ...              ...      ...     ...  ...     ...
# 245    Larvitar     720               60     rock  ground   50      64
# 246     Pupitar    1520              144     rock  ground   70      84
# 247   Tyranitar    2020              270     rock    dark  100     134
# 248       Lugia    2160              306  psychic  flying  106      90
# 249       Ho-oh    1990              306     fire  flying  106     130
#
#      defense  special_attack  special_defense  speed
# 0         49              65               65     45
# ...

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
ds['name'] = le.fit_transform(ds['name'])
ds['type_1'] = le.fit_transform(ds['type_1'])
ds['type_2'] = le.fit_transform(ds['type_2'])
# for col in ['name','type_1','type_2']:
#     ds[col] = le.fit_transform(ds[col])

# %%
ds
# Out:
#      name  weight  base_experience  type_1  type_2   hp  attack  defense  \
# 0       6      69               64       7      10   45      49       49
# 1      41     130              142       7      10   60      62       63
# 2     104    1000              236       7      10   80      82       83
# 5       8     905              240       5       6   78      84       78
# 11      7     320              178       0       6   60      45       50
# ..    ...     ...              ...     ...     ...  ...     ...      ...
# 245    51     720               60      13       8   50      64       50
# 246    78    1520              144      13       8   70      84       70
# 247   101    2020              270      13       0  100     134      110
# 248    54    2160              306      12       6  106      90      130
# 249    35    1990              306       5       6  106     130       90
#
#      special_attack  special_defense  speed
# 0                65               65     45
# ...

# %% [markdown]
# # extract the input feature x and traget value y

# %%
x = ds.iloc[:,:-1].values
y = ds['speed'].values

print('this is input feature that was x :-',x)
print('the target value :- \n' , y)
# Out:
# this is input feature that was x :- [[   6   69   64 ...   49   65   65]
#  [  41  130  142 ...   63   80   80]
#  [ 104 1000  236 ...   83  100  100]
#  ...
#  [ 101 2020  270 ...  110   95  100]
#  [  54 2160  306 ...  130   90  154]
#  [  35 1990  306 ...   90  110  154]]
# the target value :-
#  [ 45  60  80 100  70  50  35  75  56  71 101  70 100  76  85  20  45  55
#   90  30  40  50  25  30  45  90  70  40  55  70  70 100  20  35  45  15
#   30  45  70  60  75 110  70  70  80  95 110  70  40  55  25  40 115  90
#  105  95  81  60  35  55  55  80 130  85 100  90  80  50  70  55  85  30
#   40 130  67  67  15  40  70  95  40  50  50  80 110  95  15  35  91  30
#   85  40  85  30  85  65   5  85 115  30  50  50  35  75  70  70  65  95
#   85  65  41  51  61 110  90]

# %%
# the shape of this dataset is 

print("Shape of X:", x.shape)
print("Shape of y:", y.shape)
print("Dataset shape:", ds.shape)
# Out:
# Shape of X: (115, 10)
# Shape of y: (115,)
# Dataset shape: (115, 11)

# %% [markdown]
# detect the outliear ?

# %%
sns.boxplot(data = x)
# Out:
# <Axes: >

# %%
q1 = ds.quantile(0.25)
q3 = ds.quantile(0.75)
IQR = q3 - q1 
lower_bound = q1 - 1.5 * IQR 
upper_bound = q3 + 1.5 * IQR

print(IQR)
print(lower_bound)
print(upper_bound)
# Out:
# name                57.0
# weight             598.5
# base_experience    109.5
# type_1               8.0
# type_2               4.0
# hp                  30.5
# attack              40.0
# defense             38.5
# special_attack      45.0
# special_defense     35.0
# speed               42.0
# dtype: float64
# name               -57.00
# weight            -812.25
# base_experience    -94.25
# type_1              -7.00
# type_2               0.00
# hp                   4.25
# attack             -10.00
# defense             -7.75
# special_attack     -22.50
# special_defense     -2.50
# speed              -20.00
# dtype: float64
# name                171.00
# weight             1581.75
# base_experience     343.75
# type_1               25.00
# type_2               16.00
# hp                  126.25
# attack              150.00
# defense             146.25
# special_attack      157.50
# special_defense     137.50
# speed               148.00
# dtype: float64

# %%
ds[(ds <= lower_bound) | (ds >= upper_bound)]
# Out:
#      name  weight  base_experience  type_1  type_2  hp  attack  defense  \
# 0     NaN     NaN              NaN     NaN     NaN NaN     NaN      NaN
# 1     NaN     NaN              NaN     NaN     NaN NaN     NaN      NaN
# 2     NaN     NaN              NaN     NaN     NaN NaN     NaN      NaN
# 5     NaN     NaN              NaN     NaN     NaN NaN     NaN      NaN
# 11    NaN     NaN              NaN     NaN     NaN NaN     NaN      NaN
# ..    ...     ...              ...     ...     ...  ..     ...      ...
# 245   NaN     NaN              NaN     NaN     NaN NaN     NaN      NaN
# 246   NaN     NaN              NaN     NaN     NaN NaN     NaN      NaN
# 247   NaN  2020.0              NaN     NaN     0.0 NaN     NaN      NaN
# 248   NaN  2160.0              NaN     NaN     NaN NaN     NaN      NaN
# 249   NaN  1990.0              NaN     NaN     NaN NaN     NaN      NaN
#
#      special_attack  special_defense  speed
# 0               NaN              NaN    NaN
# ...

# %% [markdown]
# # remove the outliear

# %%
df_clean = ds[(ds >= lower_bound) & (ds <= upper_bound)]
df_clean
# Out:
#      name  weight  base_experience  type_1  type_2     hp  attack  defense  \
# 0       6    69.0               64       7      10   45.0      49     49.0
# 1      41   130.0              142       7      10   60.0      62     63.0
# 2     104  1000.0              236       7      10   80.0      82     83.0
# 5       8   905.0              240       5       6   78.0      84     78.0
# 11      7   320.0              178       0       6   60.0      45     50.0
# ..    ...     ...              ...     ...     ...    ...     ...      ...
# 245    51   720.0               60      13       8   50.0      64     50.0
# 246    78  1520.0              144      13       8   70.0      84     70.0
# 247   101     NaN              270      13       0  100.0     134    110.0
# 248    54     NaN              306      12       6  106.0      90    130.0
# 249    35     NaN              306       5       6  106.0     130     90.0
#
#      special_attack  special_defense  speed
# ...

# %% [markdown]
# # check correlation

# %%
plt.figure(figsize = (10,10))
plt.tight_layout()
corr_matrix = ds.select_dtypes(include = [int,float]).corr()
sns.heatmap(corr_matrix,annot = True , linecolor = 'black' ,cmap = 'Blues')
# Out:
# <Axes: >

# %% [markdown]
# # Feature salection

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x = pd.DataFrame(ss.fit_transform(x) , columns = x.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[130], line 3
#       1 from sklearn.preprocessing import StandardScaler
#       2 ss = StandardScaler()
# ----> 3 x = pd.DataFrame(ss.fit_transform(x) , columns = x.columns)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
x
# Out:
# array([[   6,   69,   64, ...,   49,   65,   65],
#        [  41,  130,  142, ...,   63,   80,   80],
#        [ 104, 1000,  236, ...,   83,  100,  100],
#        ...,
#        [ 101, 2020,  270, ...,  110,   95,  100],
#        [  54, 2160,  306, ...,  130,   90,  154],
#        [  35, 1990,  306, ...,   90,  110,  154]], shape=(115, 10))

# %% [markdown]
# # split the data on the basis off test and train

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2, random_state=2)
print('this shape is before the splitting the data :-',x.shape)
print('After splitting the data :- ',x_train.shape)
print(x_train)
# Out:
# this shape is before the splitting the data :- (115, 10)
# After splitting the data :-  (92, 10)
# [[ 109  120  196   10    3  140   70   45   85   50]
#  [   6   69   64    7   10   45   49   49   65   65]
#  [   8  905  240    5    6   78   84   78  109   85]
#  [  61  545  161   12    3   40   45   65  100  120]
#  [  89  795  172   15   11   95   75   80  100  110]
#  [ 107   32   39    0   10   40   35   30   20   20]
#  [  12  750  241   11    6   85   90   80   70   80]
#  [  93   20   52   10    6   40   60   30   31   31]
#  [  33    1  142    6   10   45   50   45  115   55]
#  [  72  295  142    0    7   60   95   80   60   80]
#  [  44  406  159    9   11   65   50   35  115   95]
#  [  11   50  144   15   12   65   55   95   65   95]
#  [  85  205  177    0   12   20   10  230   10  230]
#  [  79  750  151   15    8   95   85   85   65   65]
#  [  55  550  151    5   12   60   50  120   90   80]
#  [  23    1   62    6   10   30   35   30  100   35]
# ...

# %% [markdown]
# # creatign the LinearRegression Model

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# -------------------------------------------------------
# 9. PREDICTION SYSTEM
# -------------------------------------------------------

def predict_speed(name, type_1, type_2, hp, attack, defense, sp_attack, sp_defense, weight_kg, total):

    row = [[name, type_1, type_2, hp, attack, defense, sp_attack, sp_defense, weight_kg, total]]

    input_df = pd.DataFrame(row, columns=x.columns)

    input_scaled = ss.transform(input_df)

    prediction = lr.predict(input_scaled)

    return prediction[0]




print("\n------------------- PREDICTION -------------------")


pred = predict_speed(
    name=10,
    type_1=3,
    type_2=5,
    hp=80,
    attack=95,
    defense=85,
    sp_attack=100,
    sp_defense=90,
    weight_kg=72,
    total=540
)

print(pred)
# Out:
# ------------------- PREDICTION -------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[135], line 23
#      15     return prediction[0]
#      20 print("\n------------------- PREDICTION -------------------")
# ---> 23 pred = predict_speed(
#      24     name=10,
#      25     type_1=3,
#      26     type_2=5,
#      27     hp=80,
#      28     attack=95,
#      29     defense=85,
#      30     sp_attack=100,
#      31     sp_defense=90,
#      32     weight_kg=72,
#      33     total=540
#      34 )
#      36 print(pred)
#
# Cell In[135], line 9, in predict_speed(name, type_1, type_2, hp, attack, defense, sp_attack, sp_defense, weight_kg, total)
#       5 def predict_speed(name, type_1, type_2, hp, attack, defense, sp_attack, sp_defense, weight_kg, total):
# ...

# %% [markdown]
# # find the m and c value

# %%
print('this is the value of C is :-',lr.intercept_)
# Out:
# this is the value of C is :- 64.92108355459521

# %%
print('This is the value of M')
for col,coef in zip(x.columns,lr.coef_):
    print(f'{col} :- {coef}')
# Out:
# This is the value of M
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[137], line 2
#       1 print('This is the value of M')
# ----> 2 for col,coef in zip(x.columns,lr.coef_):
#       3     print(f'{col} :- {coef}')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
from sklearn.metrics import mean_absolute_error,r2_score
y_pred = lr.predict(x_test)
print('performace on this model :-',r2_score(y_test,y_pred))
print('this is the error number :- ',mean_absolute_error(y_test,y_pred))
# Out:
# performace on this model :- 0.1306545594667271
# this is the error number :-  17.136573329085223

# %% [markdown]
# # assumptin of linear regression model

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %% [markdown]
# # Homoscedasticity (constant variance)

# %%
error = y_test - y_pred
plt.scatter(y_pred,error)
plt.axhline(0,color = 'red')
plt.show()

# %% [markdown]
# # normality error should be normal distribution

# %%
sns.histplot(error, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
