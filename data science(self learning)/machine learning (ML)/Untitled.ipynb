# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %%
data = pd.DataFrame(data)
print("dataset:\ n",df)

X = df[["Experience"]].values
y = df["Salary"].values

# %%
sc_x = StandardScaler()
sc_y = StandardScaler()

# %%
X_scaled = sc_x.fit_transfrom(X)
y_scaled = sc_y.fit_transform(y)

# %%
svr_model = SVR(kernel = "rbf")
svr_model.fit(X_scaled,y_scaled.ravel())

# %%
x_range = np.linspace(min(X), 100).reshape(-1,1)
y_pred_scaled = svr_model.predict(sc_X.transform(X_range))
y_pred = sc_y.inverse_transform(y_pred_scaled.reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 x_range = np.linspace(min(X), 100).reshape(-1,1)
#       2 y_pred_scaled = svr_model.predict(sc_X.transform(X_range))
#       3 y_pred = sc_y.inverse_transform(y_pred_scaled.reshape(-1,1))
#
# NameError: name 'X' is not defined

# %%
plt.figure(figsize=(8,5))
plt.scatter(X,y,color = "red",lable = "actual Data")
plt.plot(X_range,y_pred,color = "blue",label = "SVR prediction")
plt.title("support Vect")
