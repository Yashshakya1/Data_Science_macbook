# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ds = pd.read_csv('kc_house_data.csv')
ds.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# # Basic understand on this dataset

# %%
ds.shape
# Out:
# (21613, 21)

# %%
ds.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
ds['condition'].nunique()
# Out:
# 5

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
ds.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# # eda

# %% [markdown]
# # distribution of price

# %%
orginal = ds['price']
plt.title('distribution of price ')
sns.histplot(data = ds,x =ds['price'] , bins=50, kde = True)
orginal.skew()
# Out:
# np.float64(4.024069144684714)

# %%
# normall the target using the log fuction

# %%
ds['price'] = np.log(ds['price'])
after.skew()

# %%
ds['price'].max()
# Out:
# 15.856730886823913

# %%
plt.subplot(1,2,1)
sns.histplot(data = ds, x = orginal, bins = 50, kde = True)
plt.subplot(1,2,2)
sns.histplot(data = ds, x= ds['price'], bins = 50 ,kde = True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# # Drop the irrelevent column

# %%
ds.drop(columns=['id'] , inplace = True)

# %% [markdown]
# # price comparing on previous year price

# %%
ds['year'].nunique()
# Out:
# 2

# %%
sns.barplot(data = ds, x= ds['year'], y = ds['price'])
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %% [markdown]
# # feature enginerring
# * Feature transformation

# %% [markdown]
# # Handling the missing values

# %%
# detect the missing values 
ds.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
ds
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000  12.309982         3       1.00         1180      5650
# 1      20141209T000000  13.195614         3       2.25         2570      7242
# 2      20150225T000000  12.100712         2       1.00          770     10000
# 3      20141209T000000  13.311329         4       3.00         1960      5000
# 4      20150218T000000  13.142166         3       2.00         1680      8080
# ...                ...        ...       ...        ...          ...       ...
# 21608  20140521T000000  12.793859         3       2.50         1530      1131
# 21609  20150223T000000  12.899220         4       2.50         2310      5813
# 21610  20140623T000000  12.904459         2       0.75         1020      1350
# 21611  20150116T000000  12.899220         3       2.50         1600      2388
# 21612  20141015T000000  12.691580         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0         1.0           0     0          3      7        1180              0
# 1         2.0           0     0          3      7        2170            400
# 2         1.0           0     0          3      6         770              0
# 3         1.0           0     0          5      7        1050            910
# 4         1.0           0     0          3      8        1680              0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21608     3.0           0     0          3      8        1530              0
# 21609     2.0           0     0          3      8        2310              0
# 21610     2.0           0     0          3      7        1020              0
# 21611     2.0           0     0          3      8        1600              0
# 21612     2.0           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1955             0    98178  47.5112 -122.257           1340
# 1          1951          1991    98125  47.7210 -122.319           1690
# 2          1933             0    98028  47.7379 -122.233           2720
# 3          1965             0    98136  47.5208 -122.393           1360
# 4          1987             0    98074  47.6168 -122.045           1800
# ...         ...           ...      ...      ...      ...            ...
# 21608      2009             0    98103  47.6993 -122.346           1530
# 21609      2014             0    98146  47.5107 -122.362           1830
# 21610      2009             0    98144  47.5944 -122.299           1020
# 21611      2004             0    98027  47.5345 -122.069           1410
# 21612      2008             0    98144  47.5941 -122.299           1020
#
#        sqft_lot15
# 0            5650
# 1            7639
# 2            8062
# 3            5000
# 4            7503
# ...           ...
# 21608        1509
# 21609        7200
# 21610        2007
# 21611        1287
# 21612        1357
#
# [21613 rows x 20 columns]

# %% [markdown]
# # Handling the outliear

# %%
ds_original = ds.copy()

# %%
import numpy as np

# num_cols = ds.select_dtypes(include="number").columns
num_cols = ds.drop(columns='price').select_dtypes(include='number').columns

total_outliers = 0

for col in num_cols:
    Q1 = ds[col].quantile(0.25)
    Q3 = ds[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    ds = ds[(ds[col] >= lower) & (ds[col] <= upper)]

    mask = (ds[col] < lower) | (ds[col] > upper)
    total_outliers += mask.sum()


print("Total Rows:", len(ds))
print("Total Outliers Found:", total_outliers)
print("Rows Removed: 0 (Outliers filled with median value)")
# Out:
# Total Rows: 13972
# Total Outliers Found: 0
# Rows Removed: 0 (Outliers filled with median value)

# %% [markdown]
# # how many outliers are present

# %%
for col in num_cols:
    Q1 = ds[col].quantile(0.25)
    Q3 = ds[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    print(col, ((ds[col] < lower) | (ds[col] > upper)).sum())
# Out:
# bedrooms 0
# bathrooms 0
# sqft_living 56
# sqft_lot 196
# floors 0
# waterfront 0
# view 0
# condition 0
# grade 0
# sqft_above 175
# sqft_basement 158
# yr_built 0
# yr_renovated 0
# zipcode 0
# lat 0
# long 46
# sqft_living15 50
# sqft_lot15 35

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,5))

# Before
plt.subplot(1,2,1)
sns.boxplot(data=ds_original[num_cols])
plt.title("Before Outlier Treatment")
plt.xticks(rotation=90)

# After
plt.subplot(1,2,2)
sns.boxplot(data=ds[num_cols])
plt.title("After Outlier Treatment (Median Filled)")
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# # encoding
# * In this dataset do not having a object or catagorical data

# %% [markdown]
# # feature construction

# %%
ds
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000  12.309982         3       1.00         1180      5650
# 2      20150225T000000  12.100712         2       1.00          770     10000
# 3      20141209T000000  13.311329         4       3.00         1960      5000
# 4      20150218T000000  13.142166         3       2.00         1680      8080
# 6      20140627T000000  12.458775         3       2.25         1715      6819
# ...                ...        ...       ...        ...          ...       ...
# 21608  20140521T000000  12.793859         3       2.50         1530      1131
# 21609  20150223T000000  12.899220         4       2.50         2310      5813
# 21610  20140623T000000  12.904459         2       0.75         1020      1350
# 21611  20150116T000000  12.899220         3       2.50         1600      2388
# 21612  20141015T000000  12.691580         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0         1.0           0     0          3      7        1180              0
# 2         1.0           0     0          3      6         770              0
# 3         1.0           0     0          5      7        1050            910
# 4         1.0           0     0          3      8        1680              0
# 6         2.0           0     0          3      7        1715              0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21608     3.0           0     0          3      8        1530              0
# 21609     2.0           0     0          3      8        2310              0
# 21610     2.0           0     0          3      7        1020              0
# 21611     2.0           0     0          3      8        1600              0
# 21612     2.0           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1955             0    98178  47.5112 -122.257           1340
# 2          1933             0    98028  47.7379 -122.233           2720
# 3          1965             0    98136  47.5208 -122.393           1360
# 4          1987             0    98074  47.6168 -122.045           1800
# 6          1995             0    98003  47.3097 -122.327           2238
# ...         ...           ...      ...      ...      ...            ...
# 21608      2009             0    98103  47.6993 -122.346           1530
# 21609      2014             0    98146  47.5107 -122.362           1830
# 21610      2009             0    98144  47.5944 -122.299           1020
# 21611      2004             0    98027  47.5345 -122.069           1410
# 21612      2008             0    98144  47.5941 -122.299           1020
#
#        sqft_lot15
# 0            5650
# 2            8062
# 3            5000
# 4            7503
# 6            6819
# ...           ...
# 21608        1509
# 21609        7200
# 21610        2007
# 21611        1287
# 21612        1357
#
# [13972 rows x 20 columns]

# %%
ds['date'].dtype
# Out:
# dtype('O')

# %%
ds['year'] = pd.to_datetime(ds['date']).dt.year
ds['month'] = pd.to_datetime(ds['date']).dt.month
ds['day'] = pd.to_datetime(ds['date']).dt.day

# %%
ds.drop(columns='date', inplace = True)

# %%
ds
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      12.309982         3       1.00         1180      5650     1.0
# 2      12.100712         2       1.00          770     10000     1.0
# 3      13.311329         4       3.00         1960      5000     1.0
# 4      13.142166         3       2.00         1680      8080     1.0
# 6      12.458775         3       2.25         1715      6819     2.0
# ...          ...       ...        ...          ...       ...     ...
# 21608  12.793859         3       2.50         1530      1131     3.0
# 21609  12.899220         4       2.50         2310      5813     2.0
# 21610  12.904459         2       0.75         1020      1350     2.0
# 21611  12.899220         3       2.50         1600      2388     2.0
# 21612  12.691580         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  ...  yr_built  yr_renovated  \
# 0               0     0          3      7  ...      1955             0
# 2               0     0          3      6  ...      1933             0
# 3               0     0          5      7  ...      1965             0
# 4               0     0          3      8  ...      1987             0
# 6               0     0          3      7  ...      1995             0
# ...           ...   ...        ...    ...  ...       ...           ...
# 21608           0     0          3      8  ...      2009             0
# 21609           0     0          3      8  ...      2014             0
# 21610           0     0          3      7  ...      2009             0
# 21611           0     0          3      8  ...      2004             0
# 21612           0     0          3      7  ...      2008             0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15  year  month  day
# 0        98178  47.5112 -122.257           1340        5650  2014     10   13
# 2        98028  47.7379 -122.233           2720        8062  2015      2   25
# 3        98136  47.5208 -122.393           1360        5000  2014     12    9
# 4        98074  47.6168 -122.045           1800        7503  2015      2   18
# 6        98003  47.3097 -122.327           2238        6819  2014      6   27
# ...        ...      ...      ...            ...         ...   ...    ...  ...
# 21608    98103  47.6993 -122.346           1530        1509  2014      5   21
# 21609    98146  47.5107 -122.362           1830        7200  2015      2   23
# 21610    98144  47.5944 -122.299           1020        2007  2014      6   23
# 21611    98027  47.5345 -122.069           1410        1287  2015      1   16
# 21612    98144  47.5941 -122.299           1020        1357  2014     10   15
#
# [13972 rows x 22 columns]

# %% [markdown]
# # extract the inpute feature and target column

# %%
target_col = ds['price']
input_feature = ds.drop(columns='price')

# %%
print(input_feature.shape)
target_col.shape
# Out:
# (13972, 21)
# (13972,)

# %% [raw]
# “We should apply scaling after the train-test split to prevent data leakage and ensure the model does not learn information from the test set during training.”

# %% [markdown]
# # spliting the data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(input_feature,target_col, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (11177, 21)
# (2795, 21)
# (11177,)
# (2795,)

# %% [markdown]
# # Feature Scalling

# %%
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_test.shape
x_train.shape
# Out:
# (11177, 21)

# %% [markdown]
# # create a model and train

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # intercept and slope values

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# 12.892653418276673
# [-1.51153974e-02  3.41689430e-02  6.58032056e-02 -1.50525001e-02
#   9.53447583e-03  0.00000000e+00 -5.20417043e-17  4.12360939e-02
#   1.31116572e-01  4.97925841e-02  3.00603719e-02 -1.14769220e-01
#  -5.55111512e-17 -3.24742586e-02  2.06595073e-01  2.70643172e-03
#   5.23109353e-02 -5.22685906e-02  3.03063129e-02  7.75046915e-03
#  -2.93374116e-03]

# %%
# predect

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([12.55429606, 13.60856922, 12.94847387, ..., 12.29998304,
#        13.58529896, 12.98113301], shape=(2795,))

# %% [markdown]
# # Model evaluation

# %% [markdown]
# # simpal linear regressin

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2_score = r2_score(y_test,y_pred)
print(mae)
print(mse)
print(rmse)
print(r2_score)
# Out:
# 0.17661522103634286
# 0.0520106401695585
# 0.22805841394160073
# 0.7080850322797787

# %% [markdown]
# # random forest

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=500, random_state=42)
model.fit(x_train, y_train)
pred= model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae = mean_absolute_error(y_test,pred)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
r2_score = r2_score(y_test,pred)
print(mae)
print(mse)
print(rmse)
print(r2_score)
# Out:
# 0.10824691911361961
# 0.02300272474411823
# 0.15166649183032563
# 0.8708948855606172

# %% [markdown]
# # xg bost

# %%
from sklearn.ensemble import GradientBoostingRegressor 
gbr = GradientBoostingRegressor(n_estimators=500 , learning_rate=0.05, max_depth=3,random_state=42)
gbr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.05, n_estimators=500, random_state=42)

# %%
p = gbr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae = mean_absolute_error(y_test,p)
mse = mean_squared_error(y_test, p)
rmse = np.sqrt(mse)
r2_score = r2_score(y_test,p)
print(mae)
print(mse)
print(rmse)
print(r2_score)
# Out:
# 0.10683053408089423
# 0.02198122881595601
# 0.14826067858996198
# 0.8766281345635846

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(gbr,input_feature,target_col,cv = 5,scoring='r2')
print(scores)
# Out:
# [0.87441188 0.8595199  0.86350189 0.8665856  0.87259538]

# %% [markdown]
# # this is the final accuracy

# %%
print(scores.mean())
# Out:
# 0.8673229302854487

# %% [markdown]
# # create a pkl file

# %%
import joblib

# %%
joblib.dump(model, "model.pkl")
joblib.dump(sc, "scaler.pkl")

print("\nModel and Scaler Saved Successfully!")
# Out:
# Model and Scaler Saved Successfully!
