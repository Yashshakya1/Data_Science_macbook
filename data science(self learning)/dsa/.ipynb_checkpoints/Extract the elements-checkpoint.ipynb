# %% [markdown]
# # extract the  digits

# %% [markdown]
#  # last number

# %%
n = 43987
num = n%10
print(num)
# Out:
# 7

# %% [markdown]
# # Secand last digits

# %%
n = 43987
last_number = n%10
secand_last = (n//10) % 10
print(last_number)
secand_last
# Out:
# 7
# 8

# %%
num = 43987
digits = []

while num > 0:
    digit = num % 10      # last digit
    digits.append(digit)
    num = num // 10       # remove last digit

digits.reverse()           # correct order
print(digits)
# Out:
# [4, 3, 9, 8, 7]
