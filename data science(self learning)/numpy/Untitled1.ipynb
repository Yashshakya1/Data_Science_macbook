# %% [markdown]
# # genrate random values with the help of random fuction

# %%
import numpy as np 
ar = np.random.rand(10)
print(ar)
# Out:
# [0.70887239 0.76103908 0.07452029 0.76879826 0.84911171 0.8567361
#  0.78212299 0.69803378 0.43203223 0.7358178 ]
