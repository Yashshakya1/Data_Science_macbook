# %% [markdown]
# # genrate random values with the help of random fuction

# %%
import numpy as np 
ar = np.random.rand()
print(ar)
# Out:
# 0.33505327522883543

# %% [markdown]
# # 1d

# %%
print(np.random.rand(5))
# Out:
# [0.60326052 0.43254121 0.47915066 0.63955681 0.13267977]

# %% [markdown]
# # 2d

# %%
print(np.random.rand(5,5))
# Out:
# [[0.60424656 0.84082056 0.77531232 0.67164501 0.84168411]
#  [0.73553815 0.20044784 0.08942509 0.82633791 0.7905168 ]
#  [0.47579418 0.38622141 0.81306192 0.91339874 0.90618066]
#  [0.12653318 0.73613681 0.73415815 0.00526549 0.20914496]
#  [0.79115671 0.72431893 0.97066533 0.62692458 0.17289227]]
