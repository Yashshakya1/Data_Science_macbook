# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 import libraray
#
# ModuleNotFoundError: No module named 'libraray'

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
ds = pd.Series([1,2,3,44,56,32])
print(ds)
print(ds[1])
# Out:
# 0     1
# 1     2
# 2     3
# 3    44
# 4    56
# 5    32
# dtype: int64
# 2

# %%
ds.iloc[-1]
# Out:
# np.int64(32)

# %%
ds.loc[0]
# Out:
# np.int64(1)

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# # Extract the columns

# %%
df[['species','sepal_width']]
# Out:
#        species  sepal_width
# 0       setosa          3.5
# 1       setosa          3.0
# 2       setosa          3.2
# 3       setosa          3.1
# 4       setosa          3.6
# ..         ...          ...
# 145  virginica          3.0
# 146  virginica          2.5
# 147  virginica          3.0
# 148  virginica          3.4
# 149  virginica          3.0
#
# [150 rows x 2 columns]

# %%
df[df['sepal_length'] > 5]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [118 rows x 5 columns]

# %% [markdown]
# # adding the data

# %%
df['name'] = "yash"
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  name
# 0             5.1          3.5           1.4          0.2     setosa  yash
# 1             4.9          3.0           1.4          0.2     setosa  yash
# 2             4.7          3.2           1.3          0.2     setosa  yash
# 3             4.6          3.1           1.5          0.2     setosa  yash
# 4             5.0          3.6           1.4          0.2     setosa  yash
# ..            ...          ...           ...          ...        ...   ...
# 145           6.7          3.0           5.2          2.3  virginica  yash
# 146           6.3          2.5           5.0          1.9  virginica  yash
# 147           6.5          3.0           5.2          2.0  virginica  yash
# 148           6.2          3.4           5.4          2.3  virginica  yash
# 149           5.9          3.0           5.1          1.8  virginica  yash
#
# [150 rows x 6 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  name_fw       fw  petal_length  petal_width  \
# 0             5.1          3.5  tanisha  tanisha           1.4          0.2
# 1             4.9          3.0  tanisha  tanisha           1.4          0.2
# 2             4.7          3.2  tanisha  tanisha           1.3          0.2
# 3             4.6          3.1  tanisha  tanisha           1.5          0.2
# 4             5.0          3.6  tanisha  tanisha           1.4          0.2
# ..            ...          ...      ...      ...           ...          ...
# 145           6.7          3.0  tanisha  tanisha           5.2          2.3
# 146           6.3          2.5  tanisha  tanisha           5.0          1.9
# 147           6.5          3.0  tanisha  tanisha           5.2          2.0
# 148           6.2          3.4  tanisha  tanisha           5.4          2.3
# 149           5.9          3.0  tanisha  tanisha           5.1          1.8
#
#        species  name
# 0       setosa  yash
# ...

# %%
df.drop(['name_fw','fw','name'], axis = 1)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.drop(columns = ['sepal_width','name_fw','fw','name'], inplace = True)

# %%
df
# Out:
#      sepal_length  petal_length  petal_width    species
# 0             5.1           1.4          0.2     setosa
# 1             4.9           1.4          0.2     setosa
# 2             4.7           1.3          0.2     setosa
# 3             4.6           1.5          0.2     setosa
# 4             5.0           1.4          0.2     setosa
# ..            ...           ...          ...        ...
# 145           6.7           5.2          2.3  virginica
# 146           6.3           5.0          1.9  virginica
# 147           6.5           5.2          2.0  virginica
# 148           6.2           5.4          2.3  virginica
# 149           5.9           5.1          1.8  virginica
#
# [150 rows x 4 columns]

# %%
df.drop(columns = 'species')
# Out:
#      sepal_length  petal_length  petal_width
# 0             5.1           1.4          0.2
# 1             4.9           1.4          0.2
# 2             4.7           1.3          0.2
# 3             4.6           1.5          0.2
# 4             5.0           1.4          0.2
# ..            ...           ...          ...
# 145           6.7           5.2          2.3
# 146           6.3           5.0          1.9
# 147           6.5           5.2          2.0
# 148           6.2           5.4          2.3
# 149           5.9           5.1          1.8
#
# [150 rows x 3 columns]

# %% [markdown]
# Detect the missing values in your dataset ?

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data_set = sns.load_dataset('brain_networks')
data_set
# Out:
#     network                    1                  1.1                   2  \
# 0      node                    1                    1                   1
# 1      hemi                   lh                   rh                  lh
# 2       NaN                  NaN                  NaN                 NaN
# 3         0    56.05574417114258    92.03103637695312   3.391575574874878
# 4         1     55.5472526550293     43.6900749206543  -65.49598693847656
# ..      ...                  ...                  ...                 ...
# 918     915  -7.4295125007629395    -4.81321907043457  -3.670536518096924
# 919     916   -33.55413818359375   -38.60562133789063  -25.66480255126953
# 920     917   -78.53956604003906   -74.19718933105469  -54.04159545898438
# 921     918  -103.23582458496094    -98.7442855834961  -40.10954284667969
# 922     919   -36.28886795043945  -10.762069702148438  -30.35626220703125
#
#                      2.1                    3                  3.1  \
# ...

# %%
data_set.isnull().sum()
# Out:
# network    1
# 1          1
# 1.1        1
# 2          1
# 2.1        1
#           ..
# 17.2       1
# 17.3       1
# 17.4       1
# 17.5       1
# 17.6       1
# Length: 63, dtype: int64

# %%
df['sepal_length'].isin([5.1,23])
df[df['sepal_length'].isin([5.1,23])]
# Out:
#     sepal_length  petal_length  petal_width     species
# 0            5.1           1.4          0.2      setosa
# 17           5.1           1.4          0.3      setosa
# 19           5.1           1.5          0.3      setosa
# 21           5.1           1.5          0.4      setosa
# 23           5.1           1.7          0.5      setosa
# 39           5.1           1.5          0.2      setosa
# 44           5.1           1.9          0.4      setosa
# 46           5.1           1.6          0.2      setosa
# 98           5.1           3.0          1.1  versicolor

# %%
# Check which rows in 'sepal_length' column have values 5.1 or 23
df['sepal_length'].isin([5.1,23])
# Filter the dataframe to only show rows where 'sepal_length' is either 5.1 or 23
df[df['sepal_length'].isin([5.1,23])] = 100

# %%
li = [32,35,46,5,76,76,76,6,65,34]
data = pd.Series(li)

# %%
df
# Out:
#      sepal_length  petal_length  petal_width    species
# 0           100.0         100.0        100.0        100
# 1             4.9           1.4          0.2     setosa
# 2             4.7           1.3          0.2     setosa
# 3             4.6           1.5          0.2     setosa
# 4             5.0           1.4          0.2     setosa
# ..            ...           ...          ...        ...
# 145           6.7           5.2          2.3  virginica
# 146           6.3           5.0          1.9  virginica
# 147           6.5           5.2          2.0  virginica
# 148           6.2           5.4          2.3  virginica
# 149           5.9           5.1          1.8  virginica
#
# [150 rows x 4 columns]

# %%
df.set_index('species',inplace = True)

# %%
df.loc[4]
# Out:
# sepal_length       5.0
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 4, dtype: object

# %%
df.reset_index(drop = True ,inplace = True)

# %%
df
# Out:
#      sepal_length  petal_length  petal_width
# 0           100.0         100.0        100.0
# 1             4.9           1.4          0.2
# 2             4.7           1.3          0.2
# 3             4.6           1.5          0.2
# 4             5.0           1.4          0.2
# ..            ...           ...          ...
# 145           6.7           5.2          2.3
# 146           6.3           5.0          1.9
# 147           6.5           5.2          2.0
# 148           6.2           5.4          2.3
# 149           5.9           5.1          1.8
#
# [150 rows x 3 columns]
