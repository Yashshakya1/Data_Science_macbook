# %% [markdown]
# facetplot is a figure level plot

# %% [markdown]
# col = 'column name' , col_wrap = 3 this para use for maintain the

# %% [markdown]
# row is used only in distribution plot not in relational plot
