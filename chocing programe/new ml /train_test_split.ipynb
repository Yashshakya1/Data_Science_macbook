# %%
import pandas as pd 
from sklearn.model_selection import train_test_split

# %%
ds = pd.DataFrame({
    'age':[34,45,65,78,78,54,43,56,56,90],
    'salary':[48754,54875,454545,40000,50000,340000,45000,210000,56965,908888],
    'parchased':[0,0,0,1,1,0,1,1,1,0]
})
ds
# Out:
#    age  salary  parchased
# 0   34   48754          0
# 1   45   54875          0
# 2   65  454545          0
# 3   78   40000          1
# 4   78   50000          1
# 5   54  340000          0
# 6   43   45000          1
# 7   56  210000          1
# 8   56   56965          1
# 9   90  908888          0

# %%
x = ds.drop(columns="parchased")
y = ds["parchased"]

# %%
print(x)
print(y)
# Out:
#    age  salary
# 0   34   48754
# 1   45   54875
# 2   65  454545
# 3   78   40000
# 4   78   50000
# 5   54  340000
# 6   43   45000
# 7   56  210000
# 8   56   56965
# 9   90  908888
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1
# 5    0
# 6    1
# 7    1
# 8    1
# 9    0
# Name: parchased, dtype: int64

# %%
x_test,x_train,y_test,y_train = train_test_split(x,y,test_size=0.2,
                                                 random_state=43)

# %%
print(x_test)
print(x_test.shape)
# Out:
#    age  salary
# 6   43   45000
# 8   56   56965
# 2   65  454545
# 5   54  340000
# 1   45   54875
# 7   56  210000
# 0   34   48754
# 4   78   50000
# (8, 2)

# %%
print(x_train)
print(x_train.shape)
# Out:
#    age  salary
# 3   78   40000
# 9   90  908888
# (2, 2)

# %%
print(y_train)
print(y_train.shape)
# Out:
# 3    1
# 9    0
# Name: parchased, dtype: int64
# (2,)

# %%
print(y_test)
print(y_test.shape)
# Out:
# 6    1
# 8    1
# 2    0
# 5    0
# 1    0
# 7    1
# 0    0
# 4    1
# Name: parchased, dtype: int64
# (8,)
