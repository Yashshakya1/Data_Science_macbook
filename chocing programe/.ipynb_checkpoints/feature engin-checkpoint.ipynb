# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ds = sns.load_dataset('titanic')

# %%
ds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# # Feature Transformation
# * hundling missing values
# * hundling catagorical feature [encoding]
# * outliear detection
# * feature scalling

# %% [markdown]
# # hundling missing values
# * how to drop the missing values and which factors are depend to execute the drop process

# %%
ds.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # showing the missing values in percentage

# %%
ds.isnull().mean()*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
(ds.isnull().sum() / len(ds) * 100 )
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
ds.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# # Condition for drop the missing valeus
# 1. missing values is less then 5% then you will drop the  missing valeus
# 2. data should be distribute normally if you drop the missing valeus
# 3. atrandom :- data is not in continous sequence
# * atrandom is also called the cca [complete case anylises] , mca [missing completely atrandom]

# %% [markdown]
# # Creating a plot for anylises how much data is distribute

# %%
ds['embarked'].value_counts().plot(kind = 'kde' )
# Out:
# <Axes: ylabel='Density'>

# %%
ds = ds.dropna(subset=['embarked'])

# %%
ds.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
ds['embarked'].value_counts().plot(kind = 'kde' , color = 'red')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # ploting both graph before removing the missing valuse and after removing the missing values

# %%
plt.figure(figsize= (12,5))
plt.subplot(1,2,1)
ds['embarked'].value_counts().plot(kind = 'kde' , color  ='red')
plt.subplot(1,2,2)
ds['embarked'].value_counts().plot(kind = 'kde', color = 'purple')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# * so you can see in the above graph both graph showing  having a some data distribution data
# * that's mean i drop the data without facing any issue or problem

# %% [markdown]
# # filling the missing values in numerical

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
ds = sns.load_dataset('titanic')
ds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
dt = ds[['age','fare']]
dt.isnull().mean()*100
# Out:
# age     19.86532
# fare     0.00000
# dtype: float64

# %%
# dataset['age'].fillna(dataset['age']).mean()

# %%
age_mean = dt['age'].mean()
age_median = dt['age'].mean()

# %% [markdown]
# # adding new columns that showing the mean and median

# %%
ds['new_mean'] = dt['age'].fillna(age_mean)
ds['new_median'] = dt['age'].fillna(age_median)

# %%
ds.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck  embark_town alive  alone   new_mean  new_median
# 0     man        True  NaN  Southampton    no  False  22.000000   22.000000
# 1   woman       False    C    Cherbourg   yes  False  38.000000   38.000000
# 2   woman       False  NaN  Southampton   yes   True  26.000000   26.000000
# 3   woman       False    C  Southampton   yes  False  35.000000   35.000000
# 4     man        True  NaN  Southampton    no   True  35.000000   35.000000
# 5     man        True  NaN   Queenstown    no   True  29.699118   29.699118
# 6     man        True    E  Southampton    no   True  54.000000   54.000000
# 7   child       False  NaN  Southampton    no  False   2.000000    2.000000
# 8   woman       False  NaN  Southampton   yes  False  27.000000   27.000000
# 9   child       False  NaN    Cherbourg   yes  False  14.000000   14.000000
# 10  child       False    G  Southampton   yes  False   4.000000    4.000000
# 11  woman       False    C  Southampton   yes   True  58.000000   58.000000
# 12    man        True  NaN  Southampton    no   True  20.000000   20.000000
# 13    man        True  NaN  Southampton    no  False  39.000000   39.000000
# 14  child       False  NaN  Southampton    no   True  14.000000   14.000000
# 15  woman       False  NaN  Southampton   yes   True  55.000000   55.000000
# 16  child       False  NaN   Queenstown    no  False   2.000000    2.000000
# 17    man        True  NaN  Southampton   yes   True  29.699118   29.699118
# 18  woman       False  NaN  Southampton    no  False  31.000000   31.000000
# 19  woman       False  NaN    Cherbourg   yes   True  29.699118   29.699118

# %%
dt['age'].var()
# Out:
# 211.0191247463081

# %%
fig = plt.figure()
a = fig.add_subplot(111)
ds['age'].plot(kind = 'kde', ax = a)

ds['new_mean'].plot(kind = 'kde',ax = a, color = 'red')

ds['new_median'].plot(kind = 'kde',ax = a, color = 'green')
plt.legend()
plt.show()

# %%
dt[["age","new_mean","new_median"]].boxplot()
# Out:
# <Axes: >
