# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ds = pd.read_csv('retail_sales_dataset.csv')
ds
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
ds['Age'].max()
# Out:
# 64

# %%
ds['Age'].min()
# Out:
# 18

# %% [markdown]
# # extract the age columns

# %%
bins = [18,35,50,70,90]
labels = ['young','middle','senior','old age']
ds['age_group'] = pd.cut(ds['Age'], bins = bins,labels= labels)
ds[['Age','age_group']]
# Out:
#      Age age_group
# 0     34     young
# 1     26     young
# 2     50    middle
# 3     37    middle
# 4     30     young
# ..   ...       ...
# 995   62    senior
# 996   52    senior
# 997   23     young
# 998   36    middle
# 999   47    middle
#
# [1000 rows x 2 columns]

# %%
ds.loc[ds['age_group'] == 'middle', ['Age', 'age_group']]
# Out:
#      Age age_group
# 2     50    middle
# 3     37    middle
# 5     45    middle
# 6     46    middle
# 14    42    middle
# ..   ...       ...
# 988   44    middle
# 992   48    middle
# 994   41    middle
# 998   36    middle
# 999   47    middle
#
# [313 rows x 2 columns]

# %%
ds['Year'] = pd.to_datetime(ds['Date']).dt.year
ds['Year']
# Out:
# 0      2023
# 1      2023
# 2      2023
# 3      2023
# 4      2023
#        ...
# 995    2023
# 996    2023
# 997    2023
# 998    2023
# 999    2023
# Name: Year, Length: 1000, dtype: int32

# %%
ds['month'] = pd.to_datetime(ds['Date']).dt.month
ds['month']
# Out:
# 0      11
# 1       2
# 2       1
# 3       5
# 4       5
#        ..
# 995     5
# 996    11
# 997    10
# 998    12
# 999     4
# Name: month, Length: 1000, dtype: int32

# %%
ds['day'] = pd.to_datetime(ds['Date']).dt.day
ds['day']
# Out:
# 0      24
# 1      27
# 2      13
# 3      21
# 4       6
#        ..
# 995    16
# 996    17
# 997    29
# 998     5
# 999    12
# Name: day, Length: 1000, dtype: int32

# %%
ds
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount age_group  Year  month  day
# ...

# %% [markdown]
# # create a name columns in this column add mr joy sinha

# %% [markdown]
# # this process is called feature splitting

# %%
ds['name'] = 'mr joy sinha'
ds
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount age_group  Year  month  day  \
# ...

# %% [raw]
# "mr joy sinha"
#     |
# .split(" ")
#     ↓
# ["mr", "joy", "sinha"]
#     |
# expand=True
#     ↓
# mr | joy | sinha
#     |
# assign to columns

# %% [markdown]
# # create three column intial, first and last and fill with mr , joy and sinha

# %%
ds[['initial','first','last']] = ds['name'].str.split(' ',expand= True)

# %%
# apply is used for fuction as a parameter in the apply 
# ds['initi'] = ds['name'].apply(lambda x: x.split()[0])
# ds['initi'] = ds['name'].apply(lambda x: x.split()[1])
# ds['initi'] = ds['name'].apply(lambda x: x.split()[2])

# %%
ds
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount age_group  Year  month  day  \
# ...

# %% [markdown]
# # create a new column last purchases year on the bases of data column

# %%
ds['Last_Purchase_Year'] = pd.to_datetime(ds['Date']).dt.year

# %%
ds['Last_Purchase_Year']
# Out:
# 0      2023
# 1      2023
# 2      2023
# 3      2023
# 4      2023
#        ...
# 995    2023
# 996    2023
# 997    2023
# 998    2023
# 999    2023
# Name: Last_Purchase_Year, Length: 1000, dtype: int32

# %% [markdown]
# showing the es na kab apna last purchase kya tha

# %%
current_year = pd.Timestamp.now().year
ds['Years_Since_Purchase'] = current_year - ds['Last_Purchase_Year']

# %%
ds.sample(5)
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 964             965  2023-11-09     CUST965    Male   22         Clothing
# 940             941  2023-03-19     CUST941  Female   57         Clothing
# 673             674  2023-04-16     CUST674  Female   38         Clothing
# 918             919  2023-09-09     CUST919  Female   22           Beauty
# 160             161  2023-03-22     CUST161    Male   64           Beauty
#
#      Quantity  Price per Unit  Total Amount age_group  Year  month  day  \
# 964         4              50           200     young  2023     11    9
# 940         2              25            50    senior  2023      3   19
# 673         1             300           300    middle  2023      4   16
# 918         2              25            50     young  2023      9    9
# 160         2             500          1000    senior  2023      3   22
#
#              name initial first   last  Last_Purchase_Year  \
# ...
