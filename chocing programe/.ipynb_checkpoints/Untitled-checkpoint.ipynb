# %% [markdown]
# # EDA

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ds = sns.load_dataset('titanic')
ds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# univarient anylises
# two types
# catagorical
# numerical

# %% [markdown]
# # count or pieplot for using for the catagroical data anylises

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.countplot(ds['survived'])
ds['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
ds['survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='survived'>

# %%
# 2nd graph

# %%
ds['survived'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # numerical data anylises

# %% [markdown]
# using three plot
# 1. histogram
# 2. displot
# 3. boxplot

# %%
ds.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
plt.hist(ds['age'], bins = 5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
sns.displot(ds['age'])

# %% [markdown]
# # this fuction is used for checking the skewness valuse

# %%
ds['age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
ds.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
plt.boxplot(ds['fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16a4b9bd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16a4b9e50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16a4b9a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x16a4ba0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16a4ba210>],
#  'means': []}
